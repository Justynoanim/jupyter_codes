# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\test.csv")
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.drop(['Cabin'],axis=1)
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.drop(["Cabin","Embarked"],axis=1)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare
# ...

# %%
df.fillna(39,inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.drop(["Cabin","Embarked"],axis=1)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare
# ...

# %%
df.drop(["Pclass","SibSp","Parch","Cabin","Embarked"],axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male  39.0
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male  39.0
# 417         1309                      Peter, Master. Michael J    male  39.0
#
#                  Ticket      Fare
# ...

# %%
a = df["Ticket"]
print(a.to_string())
# Out:
# 0                  330911
# 1                  363272
# 2                  240276
# 3                  315154
# 4                 3101298
# 5                    7538
# 6                  330972
# 7                  248738
# 8                    2657
# 9               A/4 48871
# 10                 349220
# 11                    694
# 12                  21228
# 13                  24065
# 14            W.E.P. 5734
# 15          SC/PARIS 2167
# 16                 233734
# 17                   2692
# 18       STON/O2. 3101270
# 19                   2696
# 20               PC 17603
# 21                C 17368
# 22               PC 17598
# 23               PC 17597
# 24               PC 17608
# 25              A/5. 3337
# 26                 113509
# 27                   2698
# 28                 113054
# 29                   2662
# 30             SC/AH 3085
# 31             C.A. 31029
# 32              C.A. 2315
# 33             W./C. 6607
# 34                  13236
# ...

# %%
b=(df.duplicated())
print(b.to_string())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male  39.0
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male  39.0
# 417         1309                      Peter, Master. Michael J    male  39.0
#
#                  Ticket      Fare
# ...

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Name', 'Sex', 'Age', 'Ticket', 'Fare'], dtype='object')

# %%
df.describe()
# Out:
#        PassengerId         Age        Fare
# count   418.000000  418.000000  418.000000
# mean   1100.500000   32.068182   35.635257
# std     120.810458   13.118994   55.840744
# min     892.000000    0.170000    0.000000
# 25%     996.250000   23.000000    7.895800
# 50%    1100.500000   32.000000   14.454200
# 75%    1204.750000   39.000000   31.500000
# max    1309.000000   76.000000  512.329200

# %%
df.loc[413, 'Ticket']=53236

# %%
df
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male  39.0
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male  39.0
# 417         1309                      Peter, Master. Michael J    male  39.0
#
#                  Ticket      Fare
# ...

# %%
df.loc[414, 'Ticket']=17758

# %%
df
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male  39.0
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male  39.0
# 417         1309                      Peter, Master. Michael J    male  39.0
#
#                  Ticket      Fare
# ...

# %%
df.loc[415, 'Ticket']=3101262

# %%
df
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male  39.0
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male  39.0
# 417         1309                      Peter, Master. Michael J    male  39.0
#
#       Ticket      Fare
# ...

# %%
df.head(20)
# Out:
#     PassengerId                                               Name     Sex  \
# 0           892                                   Kelly, Mr. James    male
# 1           893                   Wilkes, Mrs. James (Ellen Needs)  female
# 2           894                          Myles, Mr. Thomas Francis    male
# 3           895                                   Wirz, Mr. Albert    male
# 4           896       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897                         Svensson, Mr. Johan Cervin    male
# 6           898                               Connolly, Miss. Kate  female
# 7           899                       Caldwell, Mr. Albert Francis    male
# 8           900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901                            Davies, Mr. John Samuel    male
# 10          902                                   Ilieff, Mr. Ylio    male
# ...

# %%
df.loc[9, 'Ticket']=48871

# %%
df.head(20)
# Out:
#     PassengerId                                               Name     Sex  \
# 0           892                                   Kelly, Mr. James    male
# 1           893                   Wilkes, Mrs. James (Ellen Needs)  female
# 2           894                          Myles, Mr. Thomas Francis    male
# 3           895                                   Wirz, Mr. Albert    male
# 4           896       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897                         Svensson, Mr. Johan Cervin    male
# 6           898                               Connolly, Miss. Kate  female
# 7           899                       Caldwell, Mr. Albert Francis    male
# 8           900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901                            Davies, Mr. John Samuel    male
# 10          902                                   Ilieff, Mr. Ylio    male
# ...

# %%
df.loc[14, 'Ticket']=5734

# %%
df.head(20)
# Out:
#     PassengerId                                               Name     Sex  \
# 0           892                                   Kelly, Mr. James    male
# 1           893                   Wilkes, Mrs. James (Ellen Needs)  female
# 2           894                          Myles, Mr. Thomas Francis    male
# 3           895                                   Wirz, Mr. Albert    male
# 4           896       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897                         Svensson, Mr. Johan Cervin    male
# 6           898                               Connolly, Miss. Kate  female
# 7           899                       Caldwell, Mr. Albert Francis    male
# 8           900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901                            Davies, Mr. John Samuel    male
# 10          902                                   Ilieff, Mr. Ylio    male
# ...

# %%
df.loc[15,'Ticket']=2167

# %%
df.loc[18, 'Ticket']=3101270

# %%
df.head(20)
# Out:
#     PassengerId                                               Name     Sex  \
# 0           892                                   Kelly, Mr. James    male
# 1           893                   Wilkes, Mrs. James (Ellen Needs)  female
# 2           894                          Myles, Mr. Thomas Francis    male
# 3           895                                   Wirz, Mr. Albert    male
# 4           896       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897                         Svensson, Mr. Johan Cervin    male
# 6           898                               Connolly, Miss. Kate  female
# 7           899                       Caldwell, Mr. Albert Francis    male
# 8           900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901                            Davies, Mr. John Samuel    male
# 10          902                                   Ilieff, Mr. Ylio    male
# ...

# %%
df.head(50)
# Out:
#     PassengerId                                               Name     Sex  \
# 0           892                                   Kelly, Mr. James    male
# 1           893                   Wilkes, Mrs. James (Ellen Needs)  female
# 2           894                          Myles, Mr. Thomas Francis    male
# 3           895                                   Wirz, Mr. Albert    male
# 4           896       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897                         Svensson, Mr. Johan Cervin    male
# 6           898                               Connolly, Miss. Kate  female
# 7           899                       Caldwell, Mr. Albert Francis    male
# 8           900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901                            Davies, Mr. John Samuel    male
# 10          902                                   Ilieff, Mr. Ylio    male
# ...

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Name', 'Sex', 'Age', 'Ticket', 'Fare'], dtype='object')

# %%
c=df.rename(columns={'PassengerId':'Passenger_ID'})

# %%
print(c.to_string())
# Out:
#      Passenger_ID                                                             Name     Sex    Age              Ticket      Fare
# 0             892                                                 Kelly, Mr. James    male  34.50              330911    7.8292
# 1             893                                 Wilkes, Mrs. James (Ellen Needs)  female  47.00              363272    7.0000
# 2             894                                        Myles, Mr. Thomas Francis    male  62.00              240276    9.6875
# 3             895                                                 Wirz, Mr. Albert    male  27.00              315154    8.6625
# 4             896                     Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00             3101298   12.2875
# 5             897                                       Svensson, Mr. Johan Cervin    male  14.00                7538    9.2250
# ...

# %%
c=df.rename(columns={'Name':'Passenger Name'})

# %%
c
# Out:
#      PassengerId                                Passenger Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male  39.0
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male  39.0
# 417         1309                      Peter, Master. Michael J    male  39.0
#
#       Ticket      Fare
# ...

# %%
c.shape
# Out:
# (418, 6)

# %%
c.describe
# Out:
# <bound method NDFrame.describe of      PassengerId                                Passenger Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male  39.0
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male  39.0
# 417         1309                      Peter, Master. Michael J    male  39.0
#
# ...

# %%
c.dtypes
# Out:
# PassengerId         int64
# Passenger Name     object
# Sex                object
# Age               float64
# Ticket             object
# Fare              float64
# dtype: object

# %%
c
# Out:
#      PassengerId                                Passenger Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male  39.0
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male  39.0
# 417         1309                      Peter, Master. Michael J    male  39.0
#
#       Ticket      Fare
# ...

# %%
c.to_csv(r'C:\Users\user\Desktop\Cleanflightdata.csv')

# %%
d=c.rename(columns={'PassengerId': 'Passenger ID','Fare': 'Flight Fare'}).copy()

# %%
d
# Out:
#      Passenger ID                                Passenger Name     Sex   Age  \
# 0             892                              Kelly, Mr. James    male  34.5
# 1             893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2             894                     Myles, Mr. Thomas Francis    male  62.0
# 3             895                              Wirz, Mr. Albert    male  27.0
# 4             896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..            ...                                           ...     ...   ...
# 413          1305                            Spector, Mr. Woolf    male  39.0
# 414          1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415          1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416          1308                           Ware, Mr. Frederick    male  39.0
# 417          1309                      Peter, Master. Michael J    male  39.0
#
#       Ticket  Flight Fare
# ...

# %%
d.isna()
# Out:
#      Passenger ID  Passenger Name    Sex    Age  Ticket  Flight Fare
# 0           False           False  False  False   False        False
# 1           False           False  False  False   False        False
# 2           False           False  False  False   False        False
# 3           False           False  False  False   False        False
# 4           False           False  False  False   False        False
# ..            ...             ...    ...    ...     ...          ...
# 413         False           False  False  False   False        False
# 414         False           False  False  False   False        False
# 415         False           False  False  False   False        False
# 416         False           False  False  False   False        False
# 417         False           False  False  False   False        False
#
# [418 rows x 6 columns]

# %%
d.isna().sum()
# Out:
# Passenger ID      0
# Passenger Name    0
# Sex               0
# Age               0
# Ticket            0
# Flight Fare       0
# dtype: int64

# %%
d.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
d["Passenger Name"].duplicated().sum()
# Out:
# 0

# %%
d.columns
# Out:
# Index(['Passenger ID', 'Passenger Name', 'Sex', 'Age', 'Ticket',
#        'Flight Fare'],
#       dtype='object')

# %%
d['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
d.dtypes
# Out:
# Passenger ID        int64
# Passenger Name     object
# Sex                object
# Age               float64
# Ticket             object
# Flight Fare       float64
# dtype: object

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
d.columns
# Out:
# Index(['Passenger ID', 'Passenger Name', 'Sex', 'Age', 'Ticket',
#        'Flight Fare'],
#       dtype='object')

# %%
df_corr=d[['Age', 'Flight Fare']]

# %%
df_corr
# Out:
#       Age  Flight Fare
# 0    34.5       7.8292
# 1    47.0       7.0000
# 2    62.0       9.6875
# 3    27.0       8.6625
# 4    22.0      12.2875
# ..    ...          ...
# 413  39.0       8.0500
# 414  39.0     108.9000
# 415  38.5       7.2500
# 416  39.0       8.0500
# 417  39.0      22.3583
#
# [418 rows x 2 columns]

# %%
sns.heatmap(df_corr)
# Out:
# <AxesSubplot:>

# %%
ax=d['Sex'].value_counts()\
    .head(10)\
    .plot(kind='bar',title='Female Vs Male')
ax.set_xlabel('Sex')
ax.set_ylabel('Number of Passenger')
# Out:
# Text(0, 0.5, 'Number of Passenger')

# %%
#d.plot(kind='Scatter', x='Age', y='Flight Fare')
