# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\user\\Downloads\\Annual_cause_of_death.csv")

# %%
df
# Out:
#           Country Code  Year Death by executions  Deaths - Meningitis   \
# 0     Afghanistan  AFG  2007                  15                2933.0
# 1     Afghanistan  AFG  2008                  17                2731.0
# 2     Afghanistan  AFG  2009                   0                2460.0
# 3     Afghanistan  AFG  2011                   2                2327.0
# 4     Afghanistan  AFG  2012                  14                2254.0
# ...           ...  ...   ...                 ...                   ...
# 7268     Zimbabwe  ZWE  2015                 NaN                1439.0
# 7269     Zimbabwe  ZWE  2016                 NaN                1457.0
# 7270     Zimbabwe  ZWE  2017                 NaN                1460.0
# 7271     Zimbabwe  ZWE  2018                 NaN                1450.0
# 7272     Zimbabwe  ZWE  2019                 NaN                1450.0
#
#       Deaths - Alzheimer's disease   Deaths - Parkinson's disease   \
# ...

# %%
c=df.rename(columns={'Entity':Country'})
# Out:
#   Input In [4]
#     c=df.rename(columns={'Entity':Country'})
#                                             ^
# SyntaxError: EOL while scanning string literal

# %%
c

# %%
c

# %%
df

# %%
print(df.columns)

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df.duplicated()

# %%
df.describe()

# %%
df.dtypes

# %%
df.info

# %%
df.shape

# %%
df.columns

# %%
df.drop(["Code","Death by executions"],axis=1)

# %%
df.rename(columns={"Deaths - Meningitis":"Meningitis","Deaths - Alzheimer's disease":"Alzheimer","Deaths - Parkinson's disease":"Parkinson","Deaths - Nutritional deficiencies":"Nutritional Deficiencies",'Deaths - Malaria':'Malaria'},inplace=True)

# %%
c = df.copy()

# %%
c.head(1)
